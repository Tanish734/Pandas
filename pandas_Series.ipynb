# %%
import numpy as np
import pandas as pd

# %%
# Series from List

country = ['India','pakistan','Srilanka','USA','nepal']
pd.Series(country)
# Out:
# 0       India
# 1    pakistan
# 2    Srilanka
# 3         USA
# 4       nepal
# dtype: object

# %%
runs = [12,24,56,78,56]
run_ser=pd.Series(runs)

# %%
marks = [67,78,80,90]
subjects = ['Hindi','English','Science','Maths']

pd.Series(marks, index=subjects)
# Out:
# Hindi      67
# English    78
# Science    80
# Maths      90
# dtype: int64

# %%
marks= pd.Series(marks, index=subjects, name = 'Tanish of Marks')

# %%
marks
# Out:
# Hindi      67
# English    78
# Science    80
# Maths      90
# Name: Tanish of Marks, dtype: int64

# %%
# Series from dict

# %%
marks = {
    'Math':67,
    'english': 57,
    'science':89,
    'math': 90
}

marks_series=pd.Series(marks, name = 'Tanish')

# %%
# Series of Attributes

# %%
# size
marks_series.size
# Out:
# 4

# %%
marks_series.dtype
# Out:
# dtype('int64')

# %%
marks_series.name
# Out:
# 'Tanish'

# %%
marks_series.is_unique
# Out:
# True

# %%
pd.Series([1,2,1,2,1,2]).is_unique
# Out:
# False

# %%
marks_series.index
# Out:
# Index(['Math', 'english', 'science', 'math'], dtype='object')

# %%
marks_series.values
# Out:
# array([67, 57, 89, 90])

# %%
run_ser.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# Series using read_csv
bollywood=pd.read_csv('bollywood.csv',index_col = 'movie')

# %%
boll_series=pd.Series(bollywood['lead'])
(boll_series)
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
# pd.read_csv("subs.csv",squeeze = True,axis = 0)
subs = pd.read_csv("subs.csv").squeeze("columns")

# %%
a =pd.Series(subs['Subscribers gained'])
a
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
vk=pd.read_csv('kohli_ipl.csv', index_col = 'match_no').squeeze('columns')
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
pd.Series(runs['runs'])
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies=pd.read_csv('bollywood.csv',index_col = 'movie').squeeze('columns')

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
type(movies)
# Out:
# pandas.core.series.Series

# %%
subs.head(3)
# Out:
# 0    48
# 1    57
# 2    40
# Name: Subscribers gained, dtype: int64

# %%
vk.head(3)
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13

# %%
vk.tail(5)
# Out:
#           runs
# match_no
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %%
movies.sample(5)
# Out:
# movie
# Parineeta (2005 film)    Saif Ali Khan
# Inkaar (2013 film)        Arjun Rampal
# B.A. Pass                 Shadab Kamal
# Wanted (2009 film)         Salman Khan
# Elaan (2005 film)         Arjun Rampal
# Name: lead, dtype: object

# %%
movies.value_counts()
# Out:
# lead
# Akshay Kumar            48
# Amitabh Bachchan        45
# Ajay Devgn              38
# Salman Khan             31
# Sanjay Dutt             26
#                         ..
# Tanishaa Mukerji         1
# Tanuja                   1
# Ankit                    1
# Rakhee Gulzar            1
# Geetika Vidya Ohlyan     1
# Name: count, Length: 566, dtype: int64

# %%
vk.sort_values(ascending=False).head(1).values[0]
# Out:
# np.int64(113)

# %%
vk.sort_values(ascending=False)
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 120    100
# 164    100
#       ...
# 93       0
# 130      0
# 206      0
# 207      0
# 211      0
# Name: runs, Length: 215, dtype: int64

# %%
movies.sort_index(ascending = False)
# Out:
# movie
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Zokkomon                       Darsheel Safary
# Zindagi Tere Naam           Mithun Chakraborty
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi 50-50                      Veena Malik
#                                    ...
# 2 States (2014 film)              Arjun Kapoor
# 1971 (2007 film)                Manoj Bajpayee
# 1920: The Evil Returns             Vicky Ahuja
# 1920: London                     Sharman Joshi
# 1920 (film)                   Rajniesh Duggall
# Name: lead, Length: 1500, dtype: object

# %%
vk.count()
# Out:
# np.int64(215)

# %%
subs.sum()
# Out:
# np.int64(49510)

# %%
subs.mean()
# Out:
# np.float64(135.64383561643837)

# %%
print(vk.median())
# Out:
# 24.0

# %%
print(movies.mode())
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: object

# %%
print(subs.std())
# Out:
# 62.6750230372527

# %%
print(vk.var())
# Out:
# 688.0024777222343

# %%
subs.min()
# Out:
# np.int64(33)

# %%
subs.max()
# Out:
# np.int64(396)

# %%
vk.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %%
# Edting Series

marks_series[1] = 100
marks_series
# Out:
# C:\Users\tanis\AppData\Local\Temp\ipykernel_15672\1775938155.py:3: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1] = 100
# Math        67
# english    100
# science     89
# math        90
# Name: Tanish, dtype: int64

# %%
marks_series['sst'] = 90

# %%
marks_series
# Out:
# Math        67
# english    100
# science     89
# math        90
# sst         90
# Name: Tanish, dtype: int64

# %%
# slicing

# %%
run_ser[2:4] = [100,100]

# %%
run_ser
# Out:
# 0     12
# 1     24
# 2    100
# 3    100
# 4     56
# dtype: int64

# %%
run_ser[[0,1,2]] = [0,0,0]

# %%
run_ser
# Out:
# 0      0
# 1      0
# 2      0
# 3    100
# 4     56
# dtype: int64

# %%
vk[vk>=50]
# Out:
# match_no
# 15      50
# 34      58
# 41      71
# 44      56
# 45      67
# 52      70
# 57      57
# 68      73
# 71      51
# 73      58
# 74      65
# 80      57
# 81      93
# 82      99
# 85      56
# 97      67
# 99      73
# 103     51
# 104     62
# 110     82
# 116     75
# 117     79
# 119     80
# 120    100
# 122     52
# 123    108
# 126    109
# 127     75
# 128    113
# 129     54
# 131     54
# 132     62
# 134     64
# 137     55
# 141     58
# 144     57
# 145     92
# 148     68
# 152     70
# 160     84
# 162     67
# 164    100
# 175     72
# 178     90
# 182     50
# 188     72
# 197     51
# 198     53
# 209     58
# 213     73
# Name: runs, dtype: int64

# %%
num_movies=movies.value_counts()
num_movies[num_movies>20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>
